# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sales_df = pd.read_excel(r"C:\Users\Green Gen Tech\Downloads\Pizza_Sale.xlsx")

# %%
sales_df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity           order_date  \
# 0         1         1     hawaiian_m         1  2015-01-01 00:00:00
# 1         2         2  classic_dlx_m         1  2015-01-01 00:00:00
# 2         3         2  five_cheese_l         1  2015-01-01 00:00:00
# 3         4         2    ital_supr_l         1  2015-01-01 00:00:00
# 4         5         2     mexicana_m         1  2015-01-01 00:00:00
#
#   order_time  unit_price  total_price pizza_size pizza_category  \
# 0   11:38:36       13.25        13.25          M        Classic
# 1   11:57:40       16.00        16.00          M        Classic
# 2   11:57:40       18.50        18.50          L         Veggie
# 3   11:57:40       20.75        20.75          L        Supreme
# 4   11:57:40       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48604 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48613 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48597 non-null  object
#  10  pizza_ingredients  48607 non-null  object
#  11  pizza_name         48613 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
sales_df.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48613.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821494
# std    14035.529381   6180.119770      0.143077      3.621789      4.437520
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
sales_df.isnull().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id        16
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           7
# pizza_size            0
# pizza_category       23
# pizza_ingredients    13
# pizza_name            7
# dtype: int64

# %%
rows_with_all_nulls = sales_df[sales_df.isnull().all(axis=1)]
print(rows_with_all_nulls)
# Out:
# Empty DataFrame
# Columns: [pizza_id, order_id, pizza_name_id, quantity, order_date, order_time, unit_price, total_price, pizza_size, pizza_category, pizza_ingredients, pizza_name]
# Index: []

# %%
rows_with_nulls_in_col = sales_df[sales_df['pizza_name_id'].isnull()] 
print(rows_with_nulls_in_col)
# Out:
#      pizza_id  order_id pizza_name_id  quantity           order_date  \
# 36         37        15           NaN         1  2015-01-01 00:00:00
# 37         38        15           NaN         1  2015-01-01 00:00:00
# 38         39        15           NaN         1  2015-01-01 00:00:00
# 39         40        16           NaN         1  2015-01-01 00:00:00
# 40         41        16           NaN         1  2015-01-01 00:00:00
# 41         42        16           NaN         1  2015-01-01 00:00:00
# 309       310       131           NaN         1  2015-02-01 00:00:00
# 310       311       131           NaN         1  2015-02-01 00:00:00
# 311       312       132           NaN         1  2015-02-01 00:00:00
# 312       313       133           NaN         1  2015-02-01 00:00:00
# 313       314       133           NaN         1  2015-02-01 00:00:00
# 415       416       175           NaN         1  2015-03-01 00:00:00
# 416       417       176           NaN         1  2015-03-01 00:00:00
# 417       418       176           NaN         1  2015-03-01 00:00:00
# 418       419       177           NaN         1  2015-03-01 00:00:00
# 419       420       177           NaN         1  2015-03-01 00:00:00
#
#     order_time  unit_price  total_price pizza_size pizza_category  \
# 36    13:33:00       18.50        18.50          L         Veggie
# 37    13:33:00       20.75        20.75          L        Supreme
# 38    13:33:00       12.00        12.00          S        Classic
# 39    13:34:07       17.95        17.95          L         Veggie
# 40    13:34:07       12.00        12.00          S        Classic
# 41    13:34:07       20.75        20.75          L        Chicken
# 309   21:33:10       12.00        12.00          S         Veggie
# 310   21:33:10       12.50        12.50          S        Supreme
# 311   21:42:45        9.75         9.75          S        Classic
# 312   22:00:17       20.75        20.75          L        Chicken
# 313   22:00:17       16.50        16.50          L        Classic
# 415   17:50:51       20.75        20.75          L        Supreme
# 416   17:51:57       20.75        20.75          L        Chicken
# 417   17:51:57       16.50        16.50          M        Supreme
# 418   17:54:36       12.00        12.00          S        Classic
# 419   17:54:36       20.75        20.75          L        Chicken
#
#                                      pizza_ingredients  \
# 36   Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 37   Soppressata Salami, Fontina Cheese, Mozzarella...
# 38   Kalamata Olives, Feta Cheese, Tomatoes, Garlic...
# 39   Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 40   Tomatoes, Anchovies, Green Olives, Red Onions,...
# 41   Chicken, Pineapple, Tomatoes, Red Peppers, Tha...
# 309  Spinach, Mushrooms, Tomatoes, Green Olives, Fe...
# 310  Spinach, Red Onions, Pepperoni, Tomatoes, Arti...
# 311                       Mozzarella Cheese, Pepperoni
# 312  Barbecued Chicken, Red Peppers, Green Peppers,...
# 313           Sliced Ham, Pineapple, Mozzarella Cheese
# 415  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 416  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
# 417  Genoa Salami, Capocollo, Pepperoni, Tomatoes, ...
# 418  Tomatoes, Anchovies, Green Olives, Red Onions,...
# 419  Chicken, Pineapple, Tomatoes, Red Peppers, Tha...
#
#                        pizza_name
# 36          The Five Cheese Pizza
# 37          The Soppressata Pizza
# 38                The Greek Pizza
# 39          The Four Cheese Pizza
# 40           The Napolitana Pizza
# 41         The Thai Chicken Pizza
# 309        The Green Garden Pizza
# 310     The Spinach Supreme Pizza
# 311           The Pepperoni Pizza
# 312    The Barbecue Chicken Pizza
# 313            The Hawaiian Pizza
# 415     The Italian Supreme Pizza
# 416  The California Chicken Pizza
# 417       The Pepper Salami Pizza
# 418          The Napolitana Pizza
# 419        The Thai Chicken Pizza

# %%
rows_with_nulls_in_col = sales_df[sales_df['pizza_category'].isnull()] 
rows_with_nulls_in_col
# Out:
#      pizza_id  order_id   pizza_name_id  quantity           order_date  \
# 426       427       181      mexicana_l         1  2015-03-01 00:00:00
# 427       428       182    brie_carre_s         1  2015-03-01 00:00:00
# 428       429       182  peppr_salami_l         1  2015-03-01 00:00:00
# 429       430       183    napolitana_m         1  2015-03-01 00:00:00
# 430       431       183    spin_pesto_l         1  2015-03-01 00:00:00
# 431       432       183    spin_pesto_s         1  2015-03-01 00:00:00
# 432       433       184      hawaiian_l         1  2015-03-01 00:00:00
# 433       434       185      sicilian_m         1  2015-03-01 00:00:00
# 434       435       185    spin_pesto_s         1  2015-03-01 00:00:00
# 435       436       186      mexicana_l         1  2015-03-01 00:00:00
# 486       487       207    spicy_ital_l         1  2015-04-01 00:00:00
# 487       488       208       bbq_ckn_l         1  2015-04-01 00:00:00
# 488       489       208       bbq_ckn_s         1  2015-04-01 00:00:00
# 489       490       208   ckn_alfredo_m         1  2015-04-01 00:00:00
# 490       491       208     pepperoni_m         1  2015-04-01 00:00:00
# 491       492       208     the_greek_m         1  2015-04-01 00:00:00
# 511       512       219   spinach_fet_m         1  2015-04-01 00:00:00
# 512       513       220      hawaiian_s         1  2015-04-01 00:00:00
# 513       514       220   ital_cpcllo_s         1  2015-04-01 00:00:00
# 514       515       220    napolitana_l         1  2015-04-01 00:00:00
# 515       516       220    spicy_ital_l         1  2015-04-01 00:00:00
# 516       517       221   five_cheese_l         1  2015-04-01 00:00:00
# 517       518       221    prsc_argla_m         1  2015-04-01 00:00:00
#
#     order_time  unit_price  total_price pizza_size pizza_category  \
# 426   18:49:32       20.25        20.25          L            NaN
# 427   18:50:10       23.65        23.65          S            NaN
# 428   18:50:10       20.75        20.75          L            NaN
# 429   18:54:55       16.00        16.00          M            NaN
# 430   18:54:55       20.75        20.75          L            NaN
# 431   18:54:55       12.50        12.50          S            NaN
# 432   18:59:05       16.50        16.50          L            NaN
# 433   19:08:33       16.25        16.25          M            NaN
# 434   19:08:33       12.50        12.50          S            NaN
# 435   19:36:00       20.25        20.25          L            NaN
# 486   12:03:58       20.75        20.75          L            NaN
# 487   12:12:05       20.75        20.75          L            NaN
# 488   12:12:05       12.75        12.75          S            NaN
# 489   12:12:05       16.75        16.75          M            NaN
# 490   12:12:05       12.50        12.50          M            NaN
# 491   12:12:05       16.00        16.00          M            NaN
# 511   14:42:01       16.00        16.00          M            NaN
# 512   15:31:59       10.50        10.50          S            NaN
# 513   15:31:59       12.00        12.00          S            NaN
# 514   15:31:59       20.50        20.50          L            NaN
# 515   15:31:59       20.75        20.75          L            NaN
# 516   15:33:18       18.50        18.50          L            NaN
# 517   15:33:18       16.50        16.50          M            NaN
#
#                                      pizza_ingredients  \
# 426  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#
#     order_time  unit_price  total_price pizza_size pizza_category  \
# 580   22:22:13       18.50        18.50          L         Veggie
# 581   11:23:35       18.50        18.50          L         Veggie
# 582   11:23:35       16.00        16.00          M         Veggie
# 583   11:23:35       16.50        16.50          L        Classic
# 584   11:23:35       16.00        16.00          M         Veggie
# 585   11:56:06       17.50        17.50          L        Classic
# 586   11:59:04       20.75        20.75          L        Chicken
# 630   15:41:50       14.75        14.75          M         Veggie
# 631   15:49:21       16.75        16.75          M         Veggie
# 632   15:49:21       20.75        20.75          L        Chicken
# 633   16:07:03       16.75        16.75          M        Chicken
# 634   16:07:03       16.75        16.75          M        Chicken
# 635   16:20:23       16.50        16.50          M        Supreme
#
#     pizza_ingredients                                  pizza_name
# 580               NaN                       The Five Cheese Pizza
# 581               NaN                       The Five Cheese Pizza
# 582               NaN                      The Green Garden Pizza
# 583               NaN                          The Hawaiian Pizza
# 584               NaN                  The Spinach and Feta Pizza
# 585               NaN  The Pepperoni, Mushroom, and Peppers Pizza
# 586               NaN                The California Chicken Pizza
# 630               NaN                       The Four Cheese Pizza
# 631               NaN                The Italian Vegetables Pizza
# 632               NaN                 The Southwest Chicken Pizza
# 633               NaN                The California Chicken Pizza
# 634               NaN                   The Chicken Alfredo Pizza
# 635               NaN            The Prosciutto and Arugula Pizza

# %%
rows_with_nulls_in_col = sales_df[sales_df['pizza_name'].isnull()] 
rows_with_nulls_in_col
# Out:
#      pizza_id  order_id pizza_name_id  quantity           order_date  \
# 688       689       303   pepperoni_s         1  2015-05-01 00:00:00
# 689       690       304    hawaiian_s         1  2015-05-01 00:00:00
# 690       691       304    mexicana_l         1  2015-05-01 00:00:00
# 691       692       305   pepperoni_l         1  2015-05-01 00:00:00
# 692       693       305    sicilian_s         1  2015-05-01 00:00:00
# 693       694       305  spicy_ital_m         1  2015-05-01 00:00:00
# 694       695       306    big_meat_s         1  2015-05-01 00:00:00
#
#     order_time  unit_price  total_price pizza_size pizza_category  \
# 688   20:02:51        9.75         9.75          S        Classic
# 689   20:07:58       10.50        10.50          S        Classic
# 690   20:07:58       20.25        20.25          L         Veggie
# 691   20:35:40       15.25        15.25          L        Classic
# 692   20:35:40       12.25        12.25          S        Supreme
# 693   20:35:40       16.50        16.50          M        Supreme
# 694   20:37:40       12.00        12.00          S        Classic
#
#                                      pizza_ingredients pizza_name
# 688                       Mozzarella Cheese, Pepperoni        NaN
# 689           Sliced Ham, Pineapple, Mozzarella Cheese        NaN
# 690  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...        NaN
# 691                       Mozzarella Cheese, Pepperoni        NaN
# 692  Coarse Sicilian Salami, Tomatoes, Green Olives...        NaN
# 693  Capocollo, Tomatoes, Goat Cheese, Artichokes, ...        NaN
# 694  Bacon, Pepperoni, Italian Sausage, Chorizo Sau...        NaN

# %%
sales_df['order_date'] = pd.to_datetime(sales_df['order_date'])

# %%
print(sales_df['order_date'])
# Out:
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-01
#            ...
# 48615   2015-12-31
# 48616   2015-12-31
# 48617   2015-12-31
# 48618   2015-12-31
# 48619   2015-12-31
# Name: order_date, Length: 48620, dtype: datetime64[ns]

# %%
# Convert order_time to datetime with a specified format
sales_df['order_time'] = pd.to_datetime(sales_df['order_time'], format='%H:%M:%S', errors='coerce')

# Extract only the time portion, if conversion was successful
sales_df['order_time'] = sales_df['order_time'].dt.time

# %%
print(sales_df["order_time"])
# Out:
# 0        11:38:36
# 1        11:57:40
# 2        11:57:40
# 3        11:57:40
# 4        11:57:40
#            ...
# 48615    21:23:10
# 48616    21:23:10
# 48617    21:23:10
# 48618    22:09:54
# 48619    23:02:05
# Name: order_time, Length: 48620, dtype: object

# %%
# Fill missing pizza_category based on most frequent category for each pizza_name
sales_df['pizza_category'] = sales_df.groupby('pizza_name')['pizza_category'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)

# Now fill remaining missing pizza_category based on pizza_name_id if available
sales_df['pizza_category'] = sales_df.groupby('pizza_name_id')['pizza_category'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x).where(sales_df['pizza_category'].isnull(), sales_df['pizza_category'])

# %%
sales_df['pizza_category'].isnull().sum()
# Out:
# 0

# %%
# Fill missing pizza_category based on most frequent category for each pizza_name
sales_df['pizza_name'] = sales_df.groupby('pizza_category')['pizza_name'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)

# Now fill remaining missing pizza_category based on pizza_name_id if available
sales_df['pizza_name'] = sales_df.groupby('pizza_name_id')['pizza_name'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x).where(sales_df['pizza_name'].isnull(), sales_df['pizza_name'])

# %%
sales_df['pizza_name'].isnull().sum()
# Out:
# 0

# %%
# Fill missing pizza_category based on most frequent category for each pizza_name
sales_df['pizza_name_id'] = sales_df.groupby('pizza_category')['pizza_name'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)

# Now fill remaining missing pizza_category based on pizza_name_id if available
sales_df['pizza_name_id'] = sales_df.groupby('pizza_ingredients')['pizza_name'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x).where(sales_df['pizza_name_id'].isnull(), sales_df['pizza_name_id'])

# %%
sales_df['pizza_name_id'].isnull().sum()
# Out:
# 0

# %%
# Fill missing pizza_category based on most frequent category for each pizza_name
sales_df['pizza_ingredients'] = sales_df.groupby('pizza_category')['pizza_name'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x)

# Now fill remaining missing pizza_category based on pizza_name_id if available
sales_df['pizza_ingredients'] = sales_df.groupby('pizza_ingredients')['pizza_name'] \
    .transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.mode().empty else x).where(sales_df['pizza_ingredients'].isnull(), sales_df['pizza_ingredients'])

# %%
sales_df['pizza_ingredients'].isnull().sum()
# Out:
# 0

# %%
# 1. Calculate total_price if quantity and unit_price are available
sales_df['total_price'] = sales_df['total_price'].fillna(sales_df['quantity'] * sales_df['unit_price'])

# 2. Fill remaining missing total_price based on the average total_price for each pizza_name and pizza_category group
sales_df['total_price'] = sales_df.groupby(['pizza_name', 'pizza_category'])['total_price'] \
                                  .transform(lambda x: x.fillna(x.mean()))

# %%
sales_df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
# Save the preprocessed DataFrame to an Excel file
sales_df.to_excel("preprocessed_sales_data.xlsx", index=False)

# %%
# Load the preprocessed dataset
sales_df = pd.read_excel("preprocessed_sales_data.xlsx")

# %%
Q1 = sales_df['total_price'].quantile(0.25)
Q3 = sales_df['total_price'].quantile(0.75)
IQR = Q3 - Q1
outliers = sales_df[(sales_df['total_price'] < Q1 - 1.5 * IQR) | (sales_df['total_price'] > Q3 + 1.5 * IQR)]
print(outliers)
# Out:
#        pizza_id  order_id                     pizza_name_id  quantity  \
# 183         184        78           The Spicy Italian Pizza         3
# 211         212        91        The Barbecue Chicken Pizza         2
# 341         342       144        The Barbecue Chicken Pizza         3
# 456         457       193         The Chicken Alfredo Pizza         2
# 611         612       271      The California Chicken Pizza         2
# ...         ...       ...                               ...       ...
# 48396     48397     21251             The Four Cheese Pizza         2
# 48417     48418     21260  The Prosciutto and Arugula Pizza         2
# 48466     48467     21288          The Classic Deluxe Pizza         3
# 48575     48576     21331        The Barbecue Chicken Pizza         2
# 48601     48602     21343           The Spicy Italian Pizza         2
#
#                    order_date order_time  unit_price  total_price pizza_size  \
# 183   1970-01-01 05:30:42.036   12:28:14       20.75        62.25          L
# 211   1970-01-01 05:30:42.036   15:14:43       20.75        41.50          L
# 341   1970-01-01 05:30:42.064   13:44:28       16.75        50.25          M
# 456   1970-01-01 05:30:42.064   20:55:47       20.75        41.50          L
# 611   1970-01-01 05:30:42.125   14:22:19       16.75        33.50          M
# ...                       ...        ...         ...          ...        ...
# 48396 1970-01-01 05:30:42.368   12:45:20       17.95        35.90          L
# 48417 1970-01-01 05:30:42.368   15:45:32       16.50        33.00          M
# 48466 1970-01-01 05:30:42.369   13:04:18       16.00        48.00          M
# 48575 1970-01-01 05:30:42.369   19:05:04       20.75        41.50          L
# 48601 1970-01-01 05:30:42.369   20:27:23       20.75        41.50          L
#
#       pizza_category                 pizza_ingredients  \
# 183          Supreme           The Spicy Italian Pizza
# 211          Chicken        The Barbecue Chicken Pizza
# 341          Chicken        The Barbecue Chicken Pizza
# 456          Chicken         The Chicken Alfredo Pizza
# 611          Chicken      The California Chicken Pizza
# ...              ...                               ...
# 48396         Veggie             The Four Cheese Pizza
# 48417        Supreme  The Prosciutto and Arugula Pizza
# 48466        Classic          The Classic Deluxe Pizza
# 48575        Chicken        The Barbecue Chicken Pizza
# 48601        Supreme           The Spicy Italian Pizza
#
#                              pizza_name
# 183             The Spicy Italian Pizza
# 211          The Barbecue Chicken Pizza
# 341          The Barbecue Chicken Pizza
# 456           The Chicken Alfredo Pizza
# 611        The California Chicken Pizza
# ...                                 ...
# 48396             The Four Cheese Pizza
# 48417  The Prosciutto and Arugula Pizza
# 48466          The Classic Deluxe Pizza
# 48575        The Barbecue Chicken Pizza
# 48601           The Spicy Italian Pizza
#
# [613 rows x 12 columns]

# %%
# Calculate IQR for 'quantity' and 'total_price'
for column in ['quantity', 'total_price']:
    Q1 = sales_df[column].quantile(0.25)
    Q3 = sales_df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Define outlier thresholds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

# %%
outliers = sales_df[(sales_df[column] < lower_bound) | (sales_df[column] > upper_bound)]
print(f"Outliers in '{column}':\n", outliers)
# Out:
# Outliers in 'total_price':
#         pizza_id  order_id                      pizza_name_id  quantity  \
# 48           49        17            The Mediterranean Pizza         2
# 222         223        92                    The Greek Pizza         2
# 1189       1190       522        The Italian Capocollo Pizza         2
# 2601       2602      1150             The Green Garden Pizza         2
# 2876       2877      1271           The Classic Deluxe Pizza         2
# 4370       4371      1946                 The Mexicana Pizza         2
# 5820       5821      2580                 The Mexicana Pizza         2
# 6020       6021      2670  The Vegetables + Vegetables Pizza         2
# 6526       6527      2889         The Spinach and Feta Pizza         2
# 8220       8221      3610           The Classic Deluxe Pizza         2
# 9551       9552      4186             The Green Garden Pizza         2
# 11836     11837      5200         The Spinach and Feta Pizza         2
# 13887     13888      6086           The Classic Deluxe Pizza         2
# 14229     14230      6223            The Mediterranean Pizza         2
# 15238     15239      6685           The Classic Deluxe Pizza         2
# 16001     16002      7038         The Spinach and Feta Pizza         2
# 16768     16769      7378        The Italian Capocollo Pizza         2
# 16936     16937      7454           The Classic Deluxe Pizza         2
# 17879     17880      7844               The Napolitana Pizza         2
# 18189     18190      7983           The Classic Deluxe Pizza         2
# 18622     18623      8181           The Classic Deluxe Pizza         2
# 22097     22098      9705                 The Mexicana Pizza         2
# 22571     22572      9920  The Vegetables + Vegetables Pizza         2
# 24081     24082     10580           The Classic Deluxe Pizza         2
# 24221     24222     10642  The Vegetables + Vegetables Pizza         2
# 24471     24472     10760           The Classic Deluxe Pizza         2
# 26345     26346     11599           The Classic Deluxe Pizza         2
# 45664        Classic                    The Greek Pizza
# 47421         Veggie         The Spinach and Feta Pizza
# 47703        Classic           The Classic Deluxe Pizza
# 48397        Classic        The Italian Capocollo Pizza
#
#                               pizza_name
# 48               The Mediterranean Pizza
# 222                      The Greek Pizza
# 1189         The Italian Capocollo Pizza
# 2601              The Green Garden Pizza
# 2876            The Classic Deluxe Pizza
# 4370                  The Mexicana Pizza
# 5820                  The Mexicana Pizza
# 6020   The Vegetables + Vegetables Pizza
# 6526          The Spinach and Feta Pizza
# 8220            The Classic Deluxe Pizza
# 9551              The Green Garden Pizza
# 11836         The Spinach and Feta Pizza
# 13887           The Classic Deluxe Pizza
# 14229            The Mediterranean Pizza
# 15238           The Classic Deluxe Pizza
# 16001         The Spinach and Feta Pizza
# 16768        The Italian Capocollo Pizza
# 16936           The Classic Deluxe Pizza
# 17879               The Napolitana Pizza
# 18189           The Classic Deluxe Pizza
# 18622           The Classic Deluxe Pizza
# 22097                 The Mexicana Pizza
# 22571  The Vegetables + Vegetables Pizza
# 24081           The Classic Deluxe Pizza
# 24221  The Vegetables + Vegetables Pizza
# 24471           The Classic Deluxe Pizza
# 26345           The Classic Deluxe Pizza
# 27270        The Italian Capocollo Pizza
# 27391  The Vegetables + Vegetables Pizza
# 28368           The Classic Deluxe Pizza
# 31636           The Classic Deluxe Pizza
# 32991            The Mediterranean Pizza
# 33721           The Classic Deluxe Pizza
# 36711           The Classic Deluxe Pizza
# 36991           The Classic Deluxe Pizza
# 37596           The Classic Deluxe Pizza
# 40430           The Classic Deluxe Pizza
# 42180            The Mediterranean Pizza
# 45076        The Italian Capocollo Pizza
# 45600  The Vegetables + Vegetables Pizza
# 45664                    The Greek Pizza
# 47421         The Spinach and Feta Pizza
# 47703           The Classic Deluxe Pizza
# 48397        The Italian Capocollo Pizza

# %%
# Boxplot for 'quantity'
plt.figure(figsize=(8, 4))
sns.boxplot(x=sales_df['quantity'], color='lightblue')
plt.title("Boxplot of Quantity Ordered")
plt.xlabel("Quantity")
plt.show()

# %%
# Scatter plot for 'quantity' vs 'total_price'
plt.figure(figsize=(8, 6))
plt.scatter(sales_df['quantity'], sales_df['total_price'], color='purple', alpha=0.6)
plt.title("Scatter Plot of Quantity vs. Total Price")
plt.xlabel("Quantity")
plt.ylabel("Total Price")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=sales_df['total_price'])
plt.title("Boxplot of Total Price")
plt.show()

# %%
# removed outliers
sales_df = sales_df[(sales_df['total_price'] >= Q1 - 1.5 * IQR) & (sales_df['total_price'] <= Q3 + 1.5 * IQR)]

# %%
# done transformation
sales_df['log_total_price'] = np.log1p(sales_df['total_price'])

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=sales_df['total_price'])
plt.title("Boxplot of Total Price")
plt.show()

# %%
import matplotlib.pyplot as plt

# Aggregate sales by date
daily_sales = sales_df.groupby('order_date')['total_price'].sum()

# Plot the sales trends
plt.figure(figsize=(12, 6))
plt.plot(daily_sales.index, daily_sales.values, marker='o')
plt.title('Daily Sales Trends')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# Extract month and year from the order_date
import matplotlib.pyplot as plt
sales_df['month'] = sales_df['order_date'].dt.month
sales_df['year'] = sales_df['order_date'].dt.year

# Aggregate sales by month
monthly_sales = sales_df.groupby(['year', 'month'])['total_price'].sum().unstack()

# Plot monthly sales
plt.figure(figsize=(12, 6))
monthly_sales.plot(kind='bar', stacked=True)
plt.title('Monthly Sales by Year')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# Analyze sales by pizza category
category_sales = sales_df.groupby('pizza_category')['total_price'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
category_sales.plot(kind='bar', color='skyblue')
plt.title('Sales by Pizza Category')
plt.xlabel('Pizza Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# Analyze sales by hour of the day
sales_df['order_hour'] = sales_df['order_time'].apply(lambda x: x.hour if pd.notnull(x) else None)
hourly_sales = sales_df.groupby('order_hour')['total_price'].sum()

plt.figure(figsize=(12, 6))
hourly_sales.plot(kind='bar', color='coral')
plt.title('Sales by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[110], line 14
#      11 plt.show()
#      13 # Analyze sales by hour of the day
# ---> 14 sales_df['order_hour'] = sales_df['order_time'].apply(lambda x: x.hour if pd.notnull(x) else None)
#      15 hourly_sales = sales_df.groupby('order_hour')['total_price'].sum()
#      17 plt.figure(figsize=(12, 6))
#
# File c:\Users\Green Gen Tech\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\Green Gen Tech\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Green Gen Tech\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Green Gen Tech\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Green Gen Tech\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[110], line 14, in <lambda>(x)
#      11 plt.show()
#      13 # Analyze sales by hour of the day
# ---> 14 sales_df['order_hour'] = sales_df['order_time'].apply(lambda x: x.hour if pd.notnull(x) else None)
#      15 hourly_sales = sales_df.groupby('order_hour')['total_price'].sum()
#      17 plt.figure(figsize=(12, 6))
#
# AttributeError: 'str' object has no attribute 'hour'

# %%
sales_df['order_time'] = pd.to_datetime(sales_df['order_time'], errors='coerce')

# Analyze sales by pizza category
category_sales = sales_df.groupby('pizza_category')['total_price'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
category_sales.plot(kind='bar', color='skyblue')
plt.title('Sales by Pizza Category')
plt.xlabel('Pizza Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# Analyze sales by hour of the day
sales_df['order_hour'] = sales_df['order_time'].dt.hour  # Extract hour after datetime conversion
hourly_sales = sales_df.groupby('order_hour')['total_price'].sum()

plt.figure(figsize=(12, 6))
hourly_sales.plot(kind='bar', color='coral')
plt.title('Sales by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.grid()
plt.show()
